# %% [markdown]
# <a href="https://colab.research.google.com/github/hunn99/PCVK_Ganjil_2024/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

#Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://assets.kompasiana.com/items/album/2023/10/23/gettyimages-1183327920-612x612-6535db79edff762489134802.jpg?t=o&v=770"]
#Baca dan tampilkan image
#Loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                            #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #convert color to RGB
  final_frame = cv.hconcat((image, image_2))        #concatenate image
  cv2_imshow(final_frame)                           #show image
  print('\n')

tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=612x216>
# resolusi image: tinggi x lebar =  216  x  306
# <PIL.Image.Image image mode=RGB size=306x216>

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# - kita dapat mengautorisasikannya dengan github kita (mudah untuk penyimpanan)
# - berbasis cloud dapat diakses melalui koneksi internet
# - yang paling penting kita tidak perlu menginstall sdk phyton nya
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# - Numpy -> untuk komputasi numerik. untuk array multidimensi (termasuk matriks), fungsi matematika dan aljabar.
# - Pandas -> manipulasi dan analisis data. pengolahan data berbasis baris dan kolom, penggabungan, dan agregasi data.
# - OpenCV -> untuk pemrosesan gambar dan video. Pengenalan wajah, deteksi tepi, segmentasi gambar, dan transformasi geometris.
# - Google Colab Patches -> (cv2_imshow) untuk menampilkan gambar dalam notebook colab.
# - Scikit-Image -> untuk pemrosesan gambar. io untuk membaca dan menulis gambar dari berbagai format, transform untuk transformasi geometris seperti resizing, rotating, dan warping pada gambar.
# - Pillow -> membuka, memanipulasi, dan menyimpan berbagai format file gambar
# - Matplotlib -> untuk visualisasi data
#
# Semua berguna dalam praktikum ini
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut:
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# Kode tersebut digunakan untuk mengurangi ukuran gambar menjadi 0.5 nya atau setengah dari ukuran aslinya.
#
# 4. for y in range (lebar):
#   image_3[int((tinggi)/2),y] = [255,255,255]
# Apakah kegunaan kode [255,255,255]? Jelaskan!
# Ini adalah model warna putih pada RGB, setiap angka mewakili intensitas (Red, Green, dan Biru). 255 adalah nilai maksimum setiap komponen yang menghasilkan warna putih.
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
# Pixel menyusun gambar digital, resolusi adalah ukuran atau jumlah pixel dalam gambar. Jadi jika resolusi tinggi maka mengandung banyak pixel dan menghasilkan gambar yang lebih detail dan tajam.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#Membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]
  # image_2[int((tinggi)/2),y] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
#Buat garis vertikal
for y in range (tinggi):
  image_4[y, int((lebar)/2)] = [255,255,255]
cv2_imshow(image_4)

image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
# #Buat garis diagonal
for y in range(tinggi):
  x = int(lebar/tinggi*y)
  image_5[y, x] = [255,255,255]

for y in range(tinggi):
  x = int((lebar/tinggi)*(tinggi-y-1))
  image_5[y, x] = [255,255,255]

cv2_imshow(image_5)
# Out:
# <PIL.Image.Image image mode=RGB size=612x216>
# <PIL.Image.Image image mode=RGB size=306x216>
# <PIL.Image.Image image mode=RGB size=306x216>
